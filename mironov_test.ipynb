# %%
import numpy as np
import matplotlib.pyplot as plt

#local import
import mironov as mi

# %%
#positive temperature
#input

#Clay content in %
C = 20
#Temperature in Celsius
T = np.linspace(-30, 30, 50)
#Moisture (cm^3/cm^3)
m_v = 0.2
p_d = 1

e_r = [mi.mironov_model(t, C, m_v, p_d)[0] for t in T]

plt.plot(T, [mi.mironov_model(t, C, m_v, p_d)[0] for t in T])
plt.ylabel("$\epsilon'$")
plt.xlabel(" Temperature (Celsius)")
# Out:
# Text(0.5, 0, ' Temperature (Celsius)')
